# %%
import pandas as pd

# %%
df=pd.read_csv("top_tracks_output.csv")
df
# Out:
#        dataset               key  u_index
# 0   top_tracks                id     1.00
# 1   top_tracks              name     1.00
# 2   top_tracks          loudness     0.99
# 3   top_tracks             tempo     0.99
# 4   top_tracks       duration_ms     0.99
# 5   top_tracks            energy     0.98
# 6   top_tracks           valence     0.97
# 7   top_tracks      acousticness     0.94
# 8   top_tracks      danceability     0.93
# 9   top_tracks       speechiness     0.88
# 10  top_tracks          liveness     0.83
# 11  top_tracks           artists     0.78
# 12  top_tracks  instrumentalness     0.41
# 13  top_tracks               key     0.12
# 14  top_tracks              mode     0.02
# 15  top_tracks    time_signature     0.02

# %%
df=df.sort_values('u_index',ascending=False)

# %%
df
# Out:
#        dataset               key  u_index
# 0   top_tracks                id     1.00
# 1   top_tracks              name     1.00
# 2   top_tracks          loudness     0.99
# 3   top_tracks             tempo     0.99
# 4   top_tracks       duration_ms     0.99
# 5   top_tracks            energy     0.98
# 6   top_tracks           valence     0.97
# 7   top_tracks      acousticness     0.94
# 8   top_tracks      danceability     0.93
# 9   top_tracks       speechiness     0.88
# 10  top_tracks          liveness     0.83
# 11  top_tracks           artists     0.78
# 12  top_tracks  instrumentalness     0.41
# 13  top_tracks               key     0.12
# 14  top_tracks              mode     0.02
# 15  top_tracks    time_signature     0.02

# %%
df.corr()
# Out:
#          u_index
# u_index      1.0

# %%
dff = pd.read_csv("top_tracks.csv")
dff
# Out:
#                        id                                               name  \
# 0   7qiZfU4dY1lWllzX7mPBI                                       Shape of You
# 1   5CtI0qwDJkDQGwXD1H1cL                                  Despacito - Remix
# 2   4aWmUDTfIPGksMNLV2rQP                 Despacito (Featuring Daddy Yankee)
# 3   6RUKPb4LETWmmr3iAEQkt                           Something Just Like This
# 4   3DXncPQOG4VBw3QHh3S81                                        I'm the One
# 5   7KXjTSCq5nL1LoYtL7XAw                                            HUMBLE.
# 6   3eR23VReFzcdmS7TYCrhC                    It Ain't Me (with Selena Gomez)
# 7   3B54sVLJ402zGa6Xm4YGN                                      Unforgettable
# 8   0KKkJNfGyhkQ5aFogxQAP                                 That's What I Like
# 9   3NdDpSvN911VPGivFlV5d  I Don’t Wanna Live Forever (Fifty Shades Darke...
# 10  7GX5flRQZVHRAGd6B4TmD                                      XO TOUR Llif3
# ...

# %%
dff.corr()
# Out:
#                   danceability    energy       key  loudness      mode  \
# danceability          1.000000 -0.057239 -0.068057  0.052759 -0.071724
# energy               -0.057239  1.000000  0.049560  0.709141 -0.078994
# key                  -0.068057  0.049560  1.000000 -0.053684 -0.164038
# loudness              0.052759  0.709141 -0.053684  1.000000 -0.090640
# mode                 -0.071724 -0.078994 -0.164038 -0.090640  1.000000
# speechiness           0.111775 -0.206672  0.070721 -0.443359  0.016506
# acousticness          0.039398 -0.253051  0.021402 -0.153320  0.066332
# instrumentalness     -0.019826  0.101128 -0.062148 -0.057377  0.053900
# liveness             -0.042014  0.147744 -0.012909  0.060033 -0.000182
# valence               0.423435  0.321781 -0.023195  0.407731 -0.023205
# tempo                -0.364492  0.032676  0.005246 -0.136692  0.100207
# duration_ms           0.006038 -0.090013  0.006513 -0.143251  0.114663
# ...

# %%
dff1 = pd.read_csv("gun-violence-data_01-2013_03-2018.csv")

# %%
dff1
# Out:
#         incident_id        date                 state  \
# 0            461105  2013-01-01          Pennsylvania
# 1            460726  2013-01-01            California
# 2            478855  2013-01-01                  Ohio
# 3            478925  2013-01-05              Colorado
# 4            478959  2013-01-07        North Carolina
# 5            478948  2013-01-07              Oklahoma
# 6            479363  2013-01-19            New Mexico
# 7            479374  2013-01-21             Louisiana
# 8            479389  2013-01-21            California
# 9            492151  2013-01-23              Maryland
# 10           491674  2013-01-23             Tennessee
# 11           479413  2013-01-25              Missouri
# 12           479561  2013-01-26             Louisiana
# 13           479554  2013-01-26  District of Columbia
# 14           479460  2013-01-26                  Ohio
# 15           479573  2013-02-02             Tennessee
# ...

# %%
dff1.corr()
# Out:
#                              incident_id  n_killed  n_injured  \
# incident_id                     1.000000  0.005052   0.009060
# n_killed                        0.005052  1.000000  -0.125425
# n_injured                       0.009060 -0.125425   1.000000
# incident_url_fields_missing          NaN       NaN        NaN
# congressional_district         -0.003585  0.055545  -0.007636
# latitude                        0.019365 -0.080078  -0.011379
# longitude                      -0.017031 -0.062149   0.036962
# n_guns_involved                -0.029638 -0.028200  -0.038843
# state_house_district           -0.002243 -0.006015  -0.030355
# state_senate_district          -0.007790 -0.010650  -0.044294
#
#                              incident_url_fields_missing  \
# incident_id                                          NaN
# n_killed                                             NaN
# n_injured                                            NaN
# ...

# %%
import pandas.rpy.common as com
import seaborn as sns
# %matplotlib inline
# load the R package ISLR
infert = com.importr("ISLR")

# load the Auto dataset
auto_df = com.load_data('Auto')

# calculate the correlation matrix
corr = dff1.corr()

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-c6571b5ed5bf> in <module>()
# ----> 1 import pandas.rpy.common as com
#       2 import seaborn as sns
#       3 get_ipython().magic('matplotlib inline')
#       4 # load the R package ISLR
#       5 infert = com.importr("ISLR")
#
# ModuleNotFoundError: No module named 'pandas.rpy'

# %%
import numpy as np 
from pandas import DataFrame
import seaborn as sns
# %matplotlib inline


#df = DataFrame(abs(np.random.randn(5, 4)), index=Index, columns=Cols)

sns.heatmap(dff.corr())

# %%
import numpy as np 
from pandas import DataFrame
import seaborn as sns
# %matplotlib inline


#df = DataFrame(abs(np.random.randn(5, 4)), index=Index, columns=Cols)

sns.heatmap(dff1.corr())

# %%
df=pd.read_csv("corr13.csv",index_col=0)
df
# Out:
#                    rate_code  Dropoff_latitude  Passenger_count  \
# rate_code           1.000000         -0.061244        -0.021328
# Dropoff_latitude   -0.061244          1.000000         0.006473
# Passenger_count    -0.021328          0.006473         1.000000
# Trip_distance       0.039612          0.037405         0.006300
# Fare_amount         0.034855         -0.007797         0.009124
# Extra              -0.058503          0.004145         0.012479
# MTA_tax            -0.649953          0.053196         0.020501
# Tip_amount         -0.011600          0.000218         0.002878
# Tolls_amount        0.016070         -0.002057        -0.000457
# Ehail_fee                NaN               NaN              NaN
# Total_amount        0.026888         -0.008006         0.009624
# Payment_type        0.050774         -0.012013        -0.007994
# Trip_type                NaN               NaN              NaN
# Pickup_longitude    0.043385         -0.667837        -0.005200
# ...

# %%
import numpy as np 
from pandas import DataFrame
import seaborn as sns
# %matplotlib inline


#df = DataFrame(abs(np.random.randn(5, 4)), index=Index, columns=Cols)

sns.heatmap(df.corr())

# %%
df=pd.read_csv("corr14.csv",index_col=0)
df
# Out:
#                    vendorid  rate_code  Pickup_longitude  Pickup_latitude  \
# vendorid           1.000000  -0.026399         -0.007104         0.009519
# rate_code         -0.026399   1.000000          0.036781        -0.031849
# Pickup_longitude  -0.007104   0.036781          1.000000        -0.999080
# Pickup_latitude    0.009519  -0.031849         -0.999080         1.000000
# Dropoff_longitude -0.033717   0.031312          0.294352        -0.293779
# Dropoff_latitude   0.035898  -0.026502         -0.293670         0.294649
# Passenger_count    0.082943  -0.009709         -0.001290        -0.000887
# Trip_distance      0.000938   0.045785         -0.006509         0.004122
# Fare_amount        0.014610   0.104834          0.012930        -0.015877
# Extra              0.004292  -0.114150         -0.006079         0.003292
# MTA_tax            0.025914  -0.838383         -0.033780         0.029192
# Tip_amount        -0.012259   0.001929          0.002097        -0.007616
# ...

# %%
import numpy as np 
from pandas import DataFrame
import seaborn as sns
# %matplotlib inline


#df = DataFrame(abs(np.random.randn(5, 4)), index=Index, columns=Cols)

sns.heatmap(df.corr())

# %%
df=pd.read_csv("corr15.csv",index_col=0)
df
# Out:
#                        vendorid  rate_code  Pickup_longitude  Pickup_latitude  \
# vendorid               1.000000  -0.015223         -0.019028         0.021257
# rate_code             -0.015223   1.000000          0.075848        -0.070427
# Pickup_longitude      -0.019028   0.075848          1.000000        -0.998683
# Pickup_latitude        0.021257  -0.070427         -0.998683         1.000000
# Dropoff_longitude     -0.035520   0.032524          0.245564        -0.244594
# Dropoff_latitude       0.037471  -0.027153         -0.244166         0.245605
# Passenger_count        0.085756  -0.005988         -0.005604         0.004462
# Trip_distance          0.001946   0.045163         -0.018775         0.016456
# Fare_amount            0.011833   0.129256          0.009270        -0.012082
# Extra                  0.006808  -0.144018         -0.014741         0.011919
# MTA_tax                0.003507  -0.789813         -0.079372         0.074213
# ...

# %%
import numpy as np 
from pandas import DataFrame
import seaborn as sns
# %matplotlib inline
#df = DataFrame(abs(np.random.randn(5, 4)), index=Index, columns=Cols)

sns.heatmap(df.corr())

# %%
df=pd.read_csv("corr16.csv",index_col=0)
df
# Out:
#                        VendorID  RateCodeID  Pickup_longitude  \
# VendorID               1.000000   -0.013846         -0.016941
# RateCodeID            -0.013846    1.000000          0.104985
# Pickup_longitude      -0.016941    0.104985          1.000000
# Pickup_latitude        0.019041   -0.101857         -0.993733
# Dropoff_longitude     -0.036482    0.148285          0.323246
# Dropoff_latitude       0.038510   -0.145190         -0.314018
# Passenger_count        0.080863   -0.007687         -0.006222
# Trip_distance         -0.001555    0.035561         -0.022727
# Fare_amount            0.006217    0.110134          0.000268
# Extra                  0.001260   -0.100893         -0.016480
# MTA_tax               -0.002909   -0.634079         -0.098903
# Tip_amount            -0.006896    0.001382          0.019956
# Tolls_amount          -0.000216    0.027412         -0.002272
# Ehail_fee                   NaN         NaN               NaN
# ...

# %%
import numpy as np 
from pandas import DataFrame
import seaborn as sns
# %matplotlib inline
#df = DataFrame(abs(np.random.randn(5, 4)), index=Index, columns=Cols)

sns.heatmap(df.corr())

# %%
df=pd.read_csv("corr17.csv",index_col=0)
df
# Out:
#                        VendorID  RatecodeID  PULocationID  DOLocationID  \
# VendorID               1.000000   -0.002622      0.008124      0.003320
# RatecodeID            -0.002622    1.000000      0.052891      0.022292
# PULocationID           0.008124    0.052891      1.000000      0.144903
# DOLocationID           0.003320    0.022292      0.144903      1.000000
# passenger_count        0.091114   -0.004151      0.019751      0.006059
# trip_distance          0.012494    0.059109      0.053769      0.093836
# fare_amount            0.020546    0.134212      0.045648      0.085419
# extra                 -0.009660   -0.113448      0.023818     -0.015467
# mta_tax               -0.011963   -0.753233     -0.048512     -0.011746
# tip_amount             0.001136    0.006801      0.032265      0.063094
# tolls_amount           0.000569    0.016587      0.004972      0.006016
# ehail_fee                   NaN         NaN           NaN           NaN
# ...

# %%
import numpy as np 
from pandas import DataFrame
import seaborn as sns
# %matplotlib inline
#df = DataFrame(abs(np.random.randn(5, 4)), index=Index, columns=Cols)

sns.heatmap(df.corr())
